# %%
import requests
url = "https://www.ibm.com"
r = requests.get(url)
#r.status_code
#r.request.headers

# %%
#importing some libraries
import os
from PIL import Image
from IPython.display import IFrame

# %%
url = "https://www.ibm.com/"
r = requests.get(url)

# %%
r.status_code
# Out:
# 200

# %%
print(r.request.headers)
# Out:
# {'User-Agent': 'python-requests/2.31.0', 'Accept-Encoding': 'gzip, deflate', 'Accept': '*/*', 'Connection': 'keep-alive', 'Cookie': '_abck=CC35F3ED4CD4768212C331D5BD0C7505~-1~~-1~-1~-1; bm_sz=6E25A1C8AECC92F27AEBEDC3F256F152~~4539718~4342326'}

# %%
print("request body:", r.request.body)
# Out:
# request body: None

# %%
header = r.headers
print(r.headers)
# Out:
# {'Content-Type': 'text/html;charset=utf-8', 'X-Dispatcher': 'prod-publish-1', 'X-Vhost': 'publish', 'X-Content-Type-Options': 'nosniff', 'Last-Modified': 'Mon, 16 Oct 2023 16:16:45 GMT', 'X-Frame-Options': 'SAMEORIGIN', 'CF-Cache-Status': 'DYNAMIC', 'Server': 'cloudflare', 'CF-RAY': '81719cc99e8a2425-IAD', 'Cache-Control': 'max-age=537', 'Expires': 'Mon, 16 Oct 2023 16:45:38 GMT', 'X-Akamai-Transformed': '9 12797 0 pmb=mTOE,2', 'Content-Encoding': 'gzip', 'Date': 'Mon, 16 Oct 2023 16:36:41 GMT', 'Content-Length': '13035', 'Connection': 'keep-alive', 'Vary': 'Accept-Encoding', 'Strict-Transport-Security': 'max-age=31536000'}

# %%
header["date"]
# Out:
# 'Mon, 16 Oct 2023 16:36:41 GMT'

# %%
header["Content-Type"]
# Out:
# 'text/html;charset=utf-8'

# %%
r.encoding
# Out:
# 'utf-8'

# %%
r.text[0:100]
# Out:
# '\n<!DOCTYPE HTML>\n<html lang="en-us">\n<head>\n    \n    \n    \n    \n    <meta charset="UTF-8"/>\n    <met'

# %%
# Use single quotation marks for defining string
url2 ='https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-PY0101EN-SkillsNetwork/IDSNlogo.png'
re = requests.get(url2)

# %%
print(re.headers)
# Out:
# {'Date': 'Mon, 16 Oct 2023 16:37:32 GMT', 'X-Clv-Request-Id': 'd830f005-6908-467a-a842-21f9f7b0c498', 'Server': 'Cleversafe', 'X-Clv-S3-Version': '2.5', 'Accept-Ranges': 'bytes', 'x-amz-request-id': 'd830f005-6908-467a-a842-21f9f7b0c498', 'ETag': '"8bb44578fff8fdcc3d2972be9ece0164"', 'Content-Type': 'image/png', 'Last-Modified': 'Wed, 16 Nov 2022 03:32:41 GMT', 'Content-Length': '78776'}

# %%
url='https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-PY0101EN-SkillsNetwork/labs/Module%205/data/Example1.txt'
path=os.path.join(os.getcwd(),'example1.txt')
r=requests.get(url)
with open(path,'wb') as f:
    f.write(r.content)

# %%
#GET Request
url_get='http://httpbin.org/get'
payload={"name":"Joseph","ID":"123"}
r=requests.get(url_get,params=payload)
r.url
print("request body:", r.request.body)
print("url status:", r.status_code)
print("url text:",r.text)
print("json file:",r.json())
print("printing one parameter from json file:",r.json()['args'])
# Out:
# request body: None
# url status: 200
# url text: {
#   "args": {
#     "ID": "123",
#     "name": "Joseph"
#   },
#   "headers": {
#     "Accept": "*/*",
#     "Accept-Encoding": "gzip, deflate",
#     "Host": "httpbin.org",
#     "User-Agent": "python-requests/2.31.0",
#     "X-Amzn-Trace-Id": "Root=1-652d6b2b-7b722aef3462a9e457553689"
#   },
#   "origin": "34.139.173.58",
#   "url": "http://httpbin.org/get?name=Joseph&ID=123"
# }
#
# json file: {'args': {'ID': '123', 'name': 'Joseph'}, 'headers': {'Accept': '*/*', 'Accept-Encoding': 'gzip, deflate', 'Host': 'httpbin.org', 'User-Agent': 'python-requests/2.31.0', 'X-Amzn-Trace-Id': 'Root=1-652d6b2b-7b722aef3462a9e457553689'}, 'origin': '34.139.173.58', 'url': 'http://httpbin.org/get?name=Joseph&ID=123'}
# printing one parameter from json file: {'ID': '123', 'name': 'Joseph'}

# %%
#POST REQUESTS
url_post='http://httpbin.org/post'
r_post='http://httpbin.org/post'
print("POST request URL:",r_post )

print("GET request URL:",r.url)
# Out:
# POST request URL: http://httpbin.org/post
# GET request URL: http://httpbin.org/get?name=Joseph&ID=123
